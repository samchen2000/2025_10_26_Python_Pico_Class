# %%
total = int(input("輸入數字 : "))
for i in range(1, 100, 5):
    total += i
    print(i,end="-")
    print (total)
# Out:
# 1-31
# 6-37
# 11-48
# 16-64
# 21-85
# 26-111
# 31-142
# 36-178
# 41-219
# 46-265
# 51-316
# 56-372
# 61-433
# 66-499
# 71-570
# 76-646
# 81-727
# 86-813
# 91-904
# 96-1000

# %%
import random
score = random.randint(1,10)
while True:
    if random.randint(1,10) == 5:
        break
    print(f"score : {score} , 不是5")
print("等於5")
# Out:
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# score : 10 , 不是5
# 等於5
