# %%
chinese = int(input("國文分數"))
print(type(chinese))
english = int(input("英文分數"))
print(type(english))
math = int(input("數學分數"))
print(type(math))

total = chinese + english + math
print("總分 : ", total, "分", sep = "__")
average = round(total / 3, ndigits=2)
print("平均 : ", average, "分", sep="---")
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# 總分 : __100__分
# 平均 : ---33.33---分

# %%
apple = 5
orange = 10
print(f"蘋果有 : {apple} 個, 橘子有 : {orange} 個")
print("蘋果有" + str(apple) + "個")
# Out:
# 蘋果有 : 5 個, 橘子有 : 10 個
# 蘋果有5個

# %%
import random

value = 10
i = 50
random_range = int(input("亂數範圍(1~X): "))
random_value = random.randint(1,random_range)
value += random_value
cont = 0
if random_value >= i:
    print(value)
    for value in range(1, 20):
        print(str(random_value))
        cont = cont + 1
        #print(f"我跑了{cont}")

else:
    print(value)
    for value in range(1, 10):
        print(str(random_value))
        cont = cont + 1
        #print(f"我跑了{cont}")
    if random_value <= i-20:
        for value in range(1, 5):
            print(str(random_value))
            cont = cont + 1
            #print(f"我跑了{cont}")
    else:
        for value in range(1, 15):
            print(str(random_value))
            cont = cont + 1
            #print(f"我跑了{cont}")
print("程式結束" + "我執行了" + str(cont) + "次")
# Out:
# 33
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 程式結束我執行了13次

# %%
import random

value = 0
i = 50
random_range = int(input("亂數範圍(1~X): "))
random_value = random.randint(1,random_range)
value += random_value
cont = 0
if random_value >= i:
    print(value)
    for value in range(1, 21):
        print(str(random_value) + " " + "random_value > i")
        cont = cont + 1
elif random_value < i and random_value > i-20: 
    print(value)
    for value in range(1, 6):
        print(str(random_value) + "random_value < i-20")
        cont = cont + 1
elif random_value <= 20:
    print(value)
    for value in range(1, 11):
        print(str(random_value) + "random_value <= 0")
        cont = cont + 1
else:
    for value in range(1, 15):
        print(str(random_value) + "random_value !!!!!")
        cont = cont + 1
print("程式結束" + "我執行了" + str(cont) + "次")
# Out:
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 2random_value !!!!!
# 程式結束我執行了14次

# %%
import random
score = random.randint(1,100)
presure = random.randint(30, 180)
dis = ["優", "甲", "乙", "丙", "丁"]
bol = ["很高", "偏高", "正常", "偏低", "很低"]
if score > 90:
    print(f"分數為  {score}, {dis[0]}")
elif score >= 80:
    print(f"分數為  {score}, {dis[1]}")
elif score >= 70:
    print(f"分數為  {score}, {dis[2]}")
elif score >= 60:
    print(f"分數為  {score}, {dis[3]}")
else :
    print(f"分數為  {score}, {dis[4]}")

if  score > 90 :
    print(f"分數為  {score}, {dis[0]}")
elif 90 >= score > 80:
    print(f"分數為  {score}, {dis[1]}")
elif 80 >= score > 70:
    print(f"分數為  {score}, {dis[2]}")
elif 70 >= score >= 60:
    print(f"分數為  {score}, {dis[3]}")
else :
    print(f"分數為  {score}, {dis[4]}")

if presure > 90 and presure < 120:
    print(f"血壓為 : {presure}, {bol[2]}")
elif presure <= 90 and presure > 55:
    print(f"分數為  {presure}, {bol[3]}")
elif presure <= 55:
    print(f"分數為  {presure}, {bol[4]}")
elif presure >= 120 and presure <= 150:
    print(f"分數為  {presure}, {bol[1]}")
else :
    print(f"分數為  {presure}, {bol[0]}")

if presure <= 90 or presure >= 120:
    print(f"血壓為 : {presure}, 不正常")
else :
    print(f"分數為  {presure}, 正常")    

if not(presure <= 90 or presure >= 120):
    print(f"血壓為 : {presure}, 正常")
else :
    print(f"分數為  {presure}, 不正常")
# Out:
# 分數為  30, 丁
# 分數為  30, 丁
# 分數為  61, 偏低
# 血壓為 : 61, 不正常
# 分數為  61, 不正常

# %%
a = -23.12
b = abs(a)
print(b)
c = False
d = 0
#all(['a', 'b'])

if all([b, a]) == True:
    print("這是真的!!")
else:
    print("這是假的!!!!!!!")
    
if any([c, d]) == True:
    print("這是真的!!!!!!!")
else:
    print("這是假假的!!!!!!!!!!")
    
print(ascii('b'))
print(ascii(a))
print(ascii('關於使用python的技巧'))

a = -23.5
b = abs(a)
print(f"{type(b)} : {str(b)}")

bin = 0b_1010_1010
print(bin)
oct = 0o_10_10
print(oct)
hex = 0x_1010_1010
print (hex)

# 使用 class 關鍵字定義一個名為 "Human" 的類別
class Human:
    # __init__ 方法會在建立物件時自動呼叫
    def __init__(self, name, age, sex):
        # self.name 和 self.age 是物件的屬性
        self.name = name
        self.age = age
        self.sex = sex

    # 這是類別中的一個方法
    def greet(self):
        return f"你好，我的名字是 {self.name} 今年 : {self.age} 性別 : {self.sex}"
    
def open_name(t1, t2):
    
    t3 = t1 + t2
    return t3        
# 從 Human 類別創建兩個物件實例
person1 = Human("Alice", 30, '女')
person2 = Human("Bob", 25, '男')
# 存取物件的屬性
print(person1.name)  # 輸出：Alice
print(person1.age)
print(person1.sex)
print(person2.name)
print(person2.age)   # 輸出：25
print(person2.sex)

# 呼叫物件的方法
print(person1.greet())  # 輸出：你好，我的名字是 Alice
print(person2.greet())  # 輸出：你好，我的名字是 Bob
t4 = open_name(1, 7)
print(t4)
# Out:
# 23.12
# 這是真的!!
# 這是假假的!!!!!!!!!!
# 'b'
# -23.12
# '\u95dc\u65bc\u4f7f\u7528python\u7684\u6280\u5de7'
# <class 'float'> : 23.5
# 170
# 520
# 269488144
# Alice
# 30
# 女
# Bob
# 25
# 男
# 你好，我的名字是 Alice 今年 : 30 性別 : 女
# 你好，我的名字是 Bob 今年 : 25 性別 : 男
# 8

# %%
class test_1:
    def __init__(self, a, b):
        self.a = a
        self.b = b
        c = self.a + self.b
    def math():
        d = c**2
        return d
    def result():
        print(d)
e = test_1(1, 10)        

print(e)
